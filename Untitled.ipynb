# %%
import pandas as pd

# %%
df = pd.read_csv("data/products.csv")

# %%
from sklearn.utils import shuffle
df = shuffle(df)
df.reset_index(drop=True, inplace=True)
df = df.iloc[:750000]

# %%
df.to_csv("products.csv", index=False)

# %%
pd.read_csv("products.csv")
# Out:
#                                                      urun  fiyat  \
# 0                         Pastavilla Kalem Makarna 500 gr   2.35
# 1       Pınar Protein Süt Yer Fıstığı ve Muz Aromalı 5...   6.99
# 2                         Torku Sade Kremalı Bisküvi 75 G   1.00
# 3                         Tarım Kredi Burgu Makarna 500 g   1.95
# 4                           Komili Riviera Zeytinyağı 3 L  82.90
# ...                                                   ...    ...
# 749995                                    Erikli Su 1  lt   2.25
# 749996      Uno Premium Çok Tahıllı Siyez Buğdaylı 350 gr   7.50
# 749997  Doritos Ala Turca Hashaş Domates Çeşnili Süper...   4.25
# 749998        Tropicana Malatya Kayısı Nektarı Tetra 1 Lt   3.75
# 749999                         Tat Domates Salçası 830 gr   9.95
#
#                                                      link        date  \
# 0       https://www.happycenter.com.tr/Pastavilla_500_...  2018-08-08
# 1       https://www.marketpaketi.com.tr/pinar-protein-...  2019-12-31
# 2       https://www.sanalmarket.com.tr/torku-sade-krem...  2019-02-15
# 3       https://www.carrefoursa.com/tr/tarim-kredi-bur...  2019-07-29
# 4       https://mopas.com.tr/komili-riviera-zeytinyagi...  2019-05-24
# ...                                                   ...         ...
# 749995  https://www.carrefoursa.com/tr/erikli-su-1-lt-...  2020-01-02
# 749996  https://mopas.com.tr/uno-premium-cok-tahilli-s...  2020-04-06
# 749997  https://www.happycenter.com.tr/Frito_Doritos_1...  2018-12-19
# 749998  https://www.carrefoursa.com/tr/-tropicana-mala...  2018-10-26
# 749999  https://www.happycenter.com.tr/Tat_11_Domates_...  2018-11-23
#
#        yuksek_fiyat       madde
# 0               NaN     makarna
# 1               7.1         sut
# 2               NaN     biskuvi
# 3               2.2     makarna
# 4               NaN  zeytinyagi
# ...             ...         ...
# 749995          NaN          su
# 749996          NaN       ekmek
# 749997          NaN     cipsler
# 749998          3.9  meyve suyu
# 749999          NaN       salca
#
# [750000 rows x 6 columns]
